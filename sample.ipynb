# %%
from sam_prompt.model_builder import build_prompt_function
# from huggingface_hub import login
# login()

prompt = build_prompt_function("sample.jpg")

# %%
from PIL import Image

for mask, score in prompt("axolotl"):
    image = Image.fromarray(mask)
    image.thumbnail((256, 256))
    display(image, f"Score: {score:.2f}")
# Out:
# <PIL.Image.Image image mode=1 size=256x144>
# 'Score: 0.98'
